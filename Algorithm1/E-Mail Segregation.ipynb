# %%
import pandas as pd
import os
from google.colab import drive
drive.mount('drive/')
# Out:
# Mounted at drive/

# %%
import numpy as np

# %%
os.chdir('drive/My Drive/MMB')

# %%
data=pd.read_excel("PremierUrban _team1_final.xlsx")

# %%
data.shape
# Out:
# (298, 5)

# %%
data.head(50)
# Out:
#     Sr. No.  ...                                           Email Id
# 0       NaN  ...                                                NaN
# 1       1.0  ...                          prerna@powergridindia.com
# 2       NaN  ...                                                NaN
# 3       2.0  ...                         kanchan@powergridindia.com
# 4       NaN  ...                                                NaN
# 5       3.0  ...                           jhask@powergridindia.com
# 6       NaN  ...                                                NaN
# 7       4.0  ...                            arun_tiwari27@yahoo.com
# 8       NaN  ...                                                NaN
# 9       5.0  ...                         praveen@powergridindia.com
# 10      NaN  ...                                                NaN
# 11      6.0  ...      sahu1978@gmail.com, amit_sahu2707@yahoo.co.in
# 12      NaN  ...                                                NaN
# ...

# %%
data.describe()
# Out:
#           Sr. No.  Size of Flat (Sq. Ft.)
# count  138.000000              138.000000
# mean    69.615942             1426.210145
# std     40.173406              341.757212
# min      1.000000              531.000000
# 25%     35.250000             1100.000000
# 50%     69.500000             1500.000000
# 75%    103.750000             1800.000000
# max    140.000000             1800.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 298 entries, 0 to 297
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Sr. No.                 138 non-null    float64
#  1   Name                    227 non-null    object
#  2   Contact No.             191 non-null    object
#  3   Size of Flat (Sq. Ft.)  138 non-null    float64
#  4   Email Id                125 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 11.8+ KB

# %%
data['Email Id'] = data['Email Id'].apply(lambda x: x.replace(';',',' ) if not pd.isnull(x) else np.nan)

# %%
new = data["Email Id"].str.split(",", n = 1, expand = True)

# %%
data["Email 1"]= new[0]

# %%
data["Email1"]= new[1]

# %%
new = data["Email1"].str.split(",", n = 1, expand = True)

# %%
data["Email 2"]= new[0]

# %%
 print(data.columns)
# Out:
# Index(['Sr. No.', 'Name', 'Contact No.', 'Size of Flat (Sq. Ft.)', 'Email Id',
#        'Email 1', 'Email1', 'Email 2'],
#       dtype='object')

# %%
data["Email2"]= new[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-41-1ad8c6077dbd> in <module>()
# ----> 1 data["Email2"]= new[:,1]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
#    2905                 return self._getitem_multilevel(key)
# -> 2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#    2908                 indexer = [indexer]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     356                 except ValueError as err:
#     357                     raise KeyError(key) from err
# --> 358             raise KeyError(key)
#     359         return super().get_loc(key, method=method, tolerance=tolerance)
#     360
#
# KeyError: (slice(None, None, None), 1)

# %%
new = data["email2"].str.split(",", n = 1, expand = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'email2'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-28b99a6cd08c> in <module>()
# ...

# %%
data["Email 3"] = new[0]

# %%
data["email3"] = new[1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     354                 try:
# --> 355                     return self._range.index(new_key)
#     356                 except ValueError as err:
#
# ValueError: 1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-112fadd3e197> in <module>()
# ----> 1 data["email3"] = new[1]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
#    2905                 return self._getitem_multilevel(key)
# -> 2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
# ...

# %%
new = data["Email3"].str.split(",", n = 1, expand = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Email3'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-46-8405ebdd6dfd> in <module>()
# ...

# %%
data["Email 4"] = new[0]

# %%
data.drop(columns =["Email Id"], inplace = True)

# %%
data.drop(columns =["Email1"], inplace = True)

# %%
data.drop(columns =["Email2"], inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-5c8c0db56cee> in <module>()
# ----> 1 data.drop(columns =["Email2"], inplace = True)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4172             level=level,
#    4173             inplace=inplace,
# -> 4174             errors=errors,
#    4175         )
#    4176
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3887         for axis, labels in axes.items():
#    3888             if labels is not None:
# -> 3889                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3890
#    3891         if inplace:
#
# ...

# %%
data.drop(columns =["Email3"], inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-45-95a396e0acba> in <module>()
# ----> 1 data.drop(columns =["email3"], inplace = True)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4172             level=level,
#    4173             inplace=inplace,
# -> 4174             errors=errors,
#    4175         )
#    4176
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3887         for axis, labels in axes.items():
#    3888             if labels is not None:
# -> 3889                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3890
#    3891         if inplace:
#
# ...

# %%
data.head(107)
# Out:
#      Sr. No.                                               Name  ... Email 4  Email 3
# 0        NaN                                          Powergrid  ...     NaN      NaN
# 1        1.0          Mrs. Prerna W/o Mr. Ramesh Chander Sharma  ...    None     None
# 2        NaN    & Mr. Ramesh Chander Sharma S/o Sh. H.K. Sharma  ...     NaN      NaN
# 3        2.0     Mrs. Asha Rani W/o Mr. Kanchan Kumar Choudhary  ...    None     None
# 4        NaN  & Mr. Kanchan Kumar Choudhary S/o Sh. Rukum Ke...  ...     NaN      NaN
# ..       ...                                                ...  ...     ...      ...
# 102      NaN                                                NaN  ...     NaN      NaN
# 103     52.0          Mr. Alok Kumar S/o Sh. Om Shankar Agarwal  ...    None     None
# 104      NaN                                                NaN  ...     NaN      NaN
# 105     53.0     Mr. Shailendra Verma S/o Sh. Ram Kishore Verma  ...    None     None
# ...

# %%
data['Email 2'] = data['Email 2'].apply(lambda x: x.lstrip(' ') if not pd.isnull(x) else np.nan)

# %%
data['Email 3'] = data['Email 3'].apply(lambda x: x.lstrip(' ') if not pd.isnull(x) else np.nan)

# %%
data['Email 4'] = data['Email 4'].apply(lambda x: x.lstrip(' ') if not pd.isnull(x) else np.nan)

# %%
data.to_excel("PremierUrban _team2_final.xlsx",index=False)
